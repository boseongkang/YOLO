# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# !rm -rf darknet
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       results
# build		darknet_images.py	json_mjpeg_streams.sh  scripts
# build.ps1	darknet.py		LICENSE		       src
# build.sh	darknet_video.py	Makefile	       video_yolov3.sh
# cfg		data			net_cam_v3.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		net_cam_v4.sh
# CMakeLists.txt	image_yolov4.sh		README.md
# Cloning into 'darknet'...
# remote: Enumerating objects: 14285, done.
# remote: Total 14285 (delta 0), reused 0 (delta 0), pack-reused 14285
# Receiving objects: 100% (14285/14285), 12.85 MiB | 23.45 MiB/s, done.
# Resolving deltas: 100% (9748/9748), done.

# %%
cd darknet
# Out:
# /content/darknet

# %%
# !./darknet detector train data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg data_for_colab/yolov3-tiny.conv.15 -dont_show

# %%
ls -al
# Out:
# total 244
# drwxr-xr-x 14 root root  4096 Sep  2 09:05 ./
# drwxr-xr-x  1 root root  4096 Sep  2 09:05 ../
# drwxr-xr-x  4 root root  4096 Sep  2 09:05 3rdparty/
# drwxr-xr-x  3 root root  4096 Sep  2 09:05 build/
# -rwxr-xr-x  1 root root  8453 Sep  2 09:05 build.ps1*
# -rwxr-xr-x  1 root root  2044 Sep  2 09:05 build.sh*
# drwxr-xr-x  3 root root  4096 Sep  2 09:05 cfg/
# drwxr-xr-x  2 root root  4096 Sep  2 09:05 .circleci/
# drwxr-xr-x  3 root root  4096 Sep  2 09:05 cmake/
# -rw-r--r--  1 root root 21066 Sep  2 09:05 CMakeLists.txt
# -rw-r--r--  1 root root  1363 Sep  2 09:05 DarknetConfig.cmake.in
# -rw-r--r--  1 root root  8738 Sep  2 09:05 darknet_images.py
# -rw-r--r--  1 root root 10334 Sep  2 09:05 darknet.py
# -rw-r--r--  1 root root  5274 Sep  2 09:05 darknet_video.py
# drwxr-xr-x  3 root root  4096 Sep  2 09:05 data/
# drwxr-xr-x  8 root root  4096 Sep  2 09:05 .git/
# drwxr-xr-x  4 root root  4096 Sep  2 09:05 .github/
# ...

# %%
cd /content/darknet/build/darknet/x64/data/obj
# Out:
# /content/darknet/build/darknet/x64/data/obj

# %%
# !unzip img.zip

# %%
cd /content/drive/My\ Drive/YOLO
# Out:
# /content/drive/My Drive/YOLO

# %%
ls
# Out:
# 20.08.25/  browser-photos/  data/     weight/
# 20.09.01/  darknet/         hand.mp4  yolov4.conv.137

# %%
cp yolov4.conv.137 /content/darknet/

# %%
cd /content/darknet/
# Out:
# /content/darknet

# %%
# !./darknet detector train build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4train.cfg yolov4.conv.137 -map
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
# ...

# %%
# !./darknet detector train build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4train.cfg yolov4.conv.137 -gpu 1 -map flag -dont_show
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.648009, GIOU: 0.637244), Class: 0.758311, Obj: 0.150251, No Obj: 0.000425, .5R: 0.888889, .75R: 0.333333, count: 9, class_loss = 2.774230, iou_loss = 6.210536, total_loss = 8.984766
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.753467, GIOU: 0.736895), Class: 0.993426, Obj: 0.649422, No Obj: 0.007924, .5R: 0.950000, .75R: 0.700000, count: 40, class_loss = 5.069136, iou_loss = 8.005249, total_loss = 13.074385
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.755784, GIOU: 0.744704), Class: 0.998516, Obj: 0.760371, No Obj: 0.019823, .5R: 0.966667, .75R: 0.600000, count: 30, class_loss = 1.410892, iou_loss = 1.845156, total_loss = 3.256048
#  total_bbox = 794965, rewritten_bbox = 0.000000 %
# ...

# %%
cd /content/darknet/build/darknet/x64/backup
# Out:
# /content/darknet/build/darknet/x64/backup

# %%
cp yolov4-custom.cfg yolov4train.cfg

# %%
cd /content/darknet
# Out:
# /content/darknet

# %%
# !cp yolov4train_1000.weights /content/drive/My\ Drive/YOLO/weight
# !cp yolov4train_2000.weights /content/drive/My\ Drive/YOLO/weight
# !cp yolov4train_best.weights /content/drive/My\ Drive/YOLO/weight
# !cp yolov4train_final.weights /content/drive/My\ Drive/YOLO/weight
# !cp yolov4train_last.weights /content/drive/My\ Drive/YOLO/weight

# %%
cp yolov4train_best.weights /content/drive/My\ Drive/YOLO/weight

# %%
cp yolov4train_1000.weights /content/drive/My\ Drive/YOLO/weight

# %%
# !./darknet detector train build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4train.cfg build/darknet/x64/backup/yolov4train_1000.weights -gpu 1 -dont_show -map
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.868603, GIOU: 0.867738), Class: 0.998169, Obj: 0.775952, No Obj: 0.003167, .5R: 1.000000, .75R: 1.000000, count: 19, class_loss = 2.036532, iou_loss = 9.668476, total_loss = 11.705008
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.910128, GIOU: 0.908854), Class: 0.999335, Obj: 0.891570, No Obj: 0.020832, .5R: 1.000000, .75R: 0.977273, count: 44, class_loss = 1.010666, iou_loss = 5.553030, total_loss = 6.563696
#  total_bbox = 802757, rewritten_bbox = 0.000249 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.769215, GIOU: 0.769216), Class: 0.991526, Obj: 0.885826, No Obj: 0.000108, .5R: 1.000000, .75R: 1.000000, count: 1, class_loss = 0.123328, iou_loss = 2.037056, total_loss = 2.160384
# ...

# %%
# !./darknet detector train build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4train.cfg build/darknet/x64/backup/yolov4train_final.weights -gpu 1 -map

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3_900.weights -dont_show hand.mp4 -i 0 -out_filename out.avi

# %%
cd /content/darknet
# Out:
# /content/darknet

# %%
# !./darknet detector demo  build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4train.cfg build/darknet/x64/backup/yolov4train_best.weights build/darknet/x64/data/obj/img/hand.mp4 -benchmark
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
# FPS:53.2 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.4 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.5 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.4 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.2 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.3 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.5 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.3 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.0 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:52.9 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.0 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.2 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.3 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.3 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.4 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.5 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.7 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.5 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.3 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.2 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.4 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.2 	 AVG_FPS:52.8
# Objects:
#
#
# FPS:53.0 	 AVG_FPS:52.8
# Objects:
#
#
# ...

# %%
# !./darknet detector test build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4train.cfg build/darknet/x64/backup/yolov4train_best.weights build/darknet/x64/data/obj/img/newhand1.jpg
#!./darknet detector test cfg/obj.data cfg/yolov3.cfg backup/yolov3_900.weights data/img/234.jpg
from IPython.display import Image
Image('predictions.jpg')
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
# !./darknet detector train build/darknet/x64/data/obj.data build/darknet/x64/cfg/yolov4train.cfg build/darknet/x64/backup/yolov4train_1000.weights -gpu 1 -dont_show -map
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
# ...

# %%
cd /content/a
# Out:
# /content/a

# %%
cp -r darknet /content/a
# Out:
# cp: cannot overwrite directory '/content/a/darknet' with non-directory

# %%
cp -r darknet /content/drive/My\ Drive/YOLO

# %%
# !zip -r darknet.zip ./*
# Out:
#   adding: darknet/ (stored 0%)
#   adding: darknet/image_yolov3.sh (deflated 20%)
#   adding: darknet/3rdparty/ (stored 0%)
#   adding: darknet/3rdparty/pthreads/ (stored 0%)
#   adding: darknet/3rdparty/pthreads/bin/ (stored 0%)
#   adding: darknet/3rdparty/pthreads/bin/pthreadGC2.dll (deflated 66%)
#   adding: darknet/3rdparty/pthreads/bin/pthreadVC2.dll (deflated 69%)
#   adding: darknet/3rdparty/pthreads/lib/ (stored 0%)
#   adding: darknet/3rdparty/pthreads/lib/libpthreadGC2.a (deflated 94%)
#   adding: darknet/3rdparty/pthreads/lib/pthreadVC2.lib (deflated 86%)
#   adding: darknet/3rdparty/pthreads/include/ (stored 0%)
#   adding: darknet/3rdparty/pthreads/include/sched.h (deflated 62%)
#   adding: darknet/3rdparty/pthreads/include/pthread.h (deflated 76%)
#   adding: darknet/3rdparty/pthreads/include/semaphore.h (deflated 63%)
#   adding: darknet/3rdparty/stb/ (stored 0%)
#   adding: darknet/3rdparty/stb/include/ (stored 0%)
# ...

# %%
cp darknet.zip /content/drive/My\ Drive/YOLO

# %%
ls
# Out:
# darknet/  darknet.zip
